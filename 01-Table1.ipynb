# %% [markdown]
# # Table1
#
# Generate table1

# %%
import pandas as pd
from pathlib import Path
from config import *

# %%
# Load data
Labels = pd.read_feather("Raw/ClinicalLabels.feather")

# %%
from tableone import TableOne

pd.set_option("display.max_rows", 100)
mytable = TableOne(
    Labels,
    qts + bts + ["Stenosis"],
    bts + ["Stenosis"],
    qts,
    "DataSetName",
    qts,
    pval=False,
    missing=False,
)
mytable.to_excel(TableDir / "SupplementaryTable3.xlsx")
mytable
# Out:
# /home/xutingfeng/miniforge3/envs/rapids-24.02/lib/python3.10/site-packages/tableone/preprocessors.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, column] = df[column].fillna(null_value)
# /home/xutingfeng/miniforge3/envs/rapids-24.02/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/xutingfeng/miniforge3/envs/rapids-24.02/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...
